# %% [markdown]
# # Visualizing Chipotle's Data

# %% [markdown]
# This time we are going to pull data directly from the internet.
# Special thanks to: https://github.com/justmarkham for sharing the dataset and materials.
#
# ### Step 1. Import the necessary libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
from collections import Counter
import numpy as np

# set this so the graphs open internally
# %matplotlib inline

# %% [markdown]
# ### Step 2. Import the dataset from this [address](https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv).

# %% [markdown]
# ### Step 3. Assign it to a variable called chipo.

# %%
path = '../../../../pandas_exercises_with_data/data/'
chipo = pd.read_csv(path+'chipotle.tsv', sep = '\t')

# %% [markdown]
# ### Step 4. See the first 10 entries

# %%
chipo.head(10)
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
# 5         3         1                           Chicken Bowl
# 6         3         1                          Side of Chips
# 7         4         1                          Steak Burrito
# 8         4         1                       Steak Soft Tacos
# 9         5         1                          Steak Burrito
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# ...

# %% [markdown]
# ### Step 5. Create a histogram of the top 5 items bought

# %%
top5=chipo.groupby('item_name').quantity.sum().sort_values(ascending=False).head(5)
top5=pd.DataFrame(top5)
top5.plot(kind='bar')
plt.xlabel('Items')
plt.ylabel('Price')
plt.title('Most ordered Chipotle Items')
plt.show()

# %%
x = chipo.item_name
letter_counts = Counter(x)# use the Counter class from collections to create a dictionary with keys(text) and frequency
df=pd.DataFrame.from_dict(letter_counts, orient='index')#表示将字典的keys作为index
df = df[0].sort_values(ascending = True)[45:50]
df.plot(kind='bar')
plt.xlabel('Items')
plt.ylabel('Price')
plt.title('Most ordered Chipotle Items')
plt.show()

# %% [markdown]
# ### Step 6. Create a scatterplot with the number of items orderered per order price
# #### Hint: Price should be in the X-axis and Items ordered in the Y-axis

# %%
dollarizer = lambda x: float(x[1:-1])
chipo.item_price = chipo.item_price.apply(dollarizer)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-838634a1a95c> in <module>
#       1 dollarizer = lambda x: float(x[1:-1])
# ----> 2 chipo.item_price = chipo.item_price.apply(dollarizer)
#       3 chipo
#
# C:\Anaconda3\lib\site-packages\pandas\core\series.py in apply(self, func, convert_dtype, args, **kwds)
#    4040             else:
#    4041                 values = self.astype(object).values
# -> 4042                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    4043
#    4044         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas\_libs\lib.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-6-838634a1a95c> in <lambda>(x)
# ----> 1 dollarizer = lambda x: float(x[1:-1])
#       2 chipo.item_price = chipo.item_price.apply(dollarizer)
#       3 chipo
#
# TypeError: 'float' object is not subscriptable

# %%
quantity_price=chipo.groupby('order_id')['quantity','item_price'].sum()
plt.scatter(x=quantity_price.item_price,y=quantity_price.quantity)
plt.xlabel('per_order_price')
plt.ylabel('per_order_quantity')
plt.title('Number of items ordered per order price')
# Out:
# Text(0.5, 1.0, 'Number of items ordered per order price')

# %% [markdown]
# ### Step 7. BONUS: Create a question and a graph to answer your own question.

# %%
plt.bar(left=range(top5.shape[0]),height=top5.values,tick_label=top5.index)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-15-460cbc07144c> in <module>
# ----> 1 plt.bar(left=range(top5.shape[0]),height=top5.values,tick_label=top5.index)
#
# TypeError: bar() missing 1 required positional argument: 'x'
